# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
icecream = [1, 2, 3, 4, 5]
weight = [5, 4, 3, 2, 1]

pennies = [1, 2, 3, 4, 5]
dollars = [1, 2, 3, 4, 5]

fig, ax = plt.subplots(1, 2)
ax[0].plot(icecream, weight, label = 'icecream/weight')
ax[1].plot(pennies, dollars, label = 'pennies/dollars')
